# %% [markdown]
# # 1. Which genres generate the highest ROI?
#         -Investigate from a profitabilty perspective i.e. Return on Investment (ROI) which genres genereate the highest return
#         -Investigate from a popularity/critical acclaim perspective which genres are "fan favorites"
#         -Are the same genres that are most profitable the most enjoyed?

# %%
#importing all of the libraries I plan to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from  matplotlib.ticker import FuncFormatter

# %%
#creating variable with last of all files for the project
csv_files = glob('zippedData/*.csv.gz')

# %%
csv_files
# Out:
# ['zippedData\\bom.movie_gross.csv.gz',
#  'zippedData\\imdb.name.basics.csv.gz',
#  'zippedData\\imdb.title.akas.csv.gz',
#  'zippedData\\imdb.title.basics.csv.gz',
#  'zippedData\\imdb.title.crew.csv.gz',
#  'zippedData\\imdb.title.principals.csv.gz',
#  'zippedData\\imdb.title.ratings.csv.gz',
#  'zippedData\\tmdb.movies.csv.gz',
#  'zippedData\\tn.movie_budgets.csv.gz']

# %%
#Using a for loop to create a dictionary with cleaned filenames
import os
csv_files_dict = {}
for filename in csv_files:
    filename_cleaned = os.path.basename(filename).replace('.csv','').replace('.','_')
    filename_df = pd.read_csv(filename, index_col = 0)
    csv_files_dict[filename_cleaned] = filename_df

# %%
#creating variable for movie budgets file
budgets = csv_files_dict['tn_movie_budgets_gz']

# %%
budgets.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
budgets.reset_index(inplace=True)

# %%
#id column provides no value so dropping
budgets.drop('id',axis=1,inplace=True)

# %%
#checking
budgets.head()
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#our budget and revenue columns are objects, we need to convert them to int or float in order to use them
#I do this using a lambda function and map method
budgets['worldwide_gross'] = budgets['worldwide_gross'].astype(str).apply(lambda x: int(x.replace(',','').replace('$','')))
budgets['production_budget'] = budgets['production_budget'].astype(str).apply(lambda x: int(x.replace(',','').replace('$','')))
budgets['domestic_gross'] = budgets['domestic_gross'].astype(str).apply(lambda x: int(x.replace(',','').replace('$','')))

# %%
#I also would like to convert our release date column into date time format instead of an object for later on
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 226.0+ KB

# %%
# converting release date to a date time format, creating a column for months with number (1-12) and for written i.e. Jan-Dec
import calendar
budgets['release_date'] = pd.to_datetime(budgets.release_date).sort_values(axis=0, ascending=False)
budgets['month'] = pd.DatetimeIndex(budgets.release_date).month
budgets['Month'] = budgets['month'].apply(lambda x: calendar.month_abbr[x])

# %%
budgets.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  month Month
# 0          425000000       760507625       2776345279     12   Dec
# 1          410600000       241063875       1045663875      5   May
# 2          350000000        42762350        149762350      6   Jun
# 3          330600000       459005868       1403013963      5   May
# 4          317000000       620181382       1316721747     12   Dec

# %%
#checking columns for recurring values, nothing sticks out here
for col in budgets:
    print(f"Currently checking values from col: {col}")
    print(f"Top 5 values:\n{budgets[col].value_counts(normalize=True)[:5]}")
    print('-----------------------')
# Out:
# Currently checking values from col: release_date
# Top 5 values:
# 2014-12-31    0.004151
# 2015-12-31    0.003978
# 2010-12-31    0.002594
# 2008-12-31    0.002421
# 2013-12-31    0.002248
# Name: release_date, dtype: float64
# -----------------------
# Currently checking values from col: movie
# Top 5 values:
# King Kong    0.000519
# Home         0.000519
# Halloween    0.000519
# Hercules     0.000346
# Life         0.000346
# Name: movie, dtype: float64
# -----------------------
# Currently checking values from col: production_budget
# Top 5 values:
# 20000000    0.039952
# 10000000    0.036666
# 30000000    0.030612
# 15000000    0.029920
# 25000000    0.029575
# Name: production_budget, dtype: float64
# -----------------------
# Currently checking values from col: domestic_gross
# Top 5 values:
# 0           0.094777
# 8000000     0.001557
# 2000000     0.001211
# 7000000     0.001211
# 10000000    0.001038
# Name: domestic_gross, dtype: float64
# -----------------------
# Currently checking values from col: worldwide_gross
# Top 5 values:
# 0          0.063473
# 8000000    0.001557
# 7000000    0.001038
# 2000000    0.001038
# 4000000    0.000692
# Name: worldwide_gross, dtype: float64
# -----------------------
# Currently checking values from col: month
# Top 5 values:
# 12    0.128848
# 10    0.099101
# 8     0.085783
# 9     0.085265
# 11    0.084054
# Name: month, dtype: float64
# -----------------------
# Currently checking values from col: Month
# Top 5 values:
# Dec    0.128848
# Oct    0.099101
# Aug    0.085783
# Sep    0.085265
# Nov    0.084054
# Name: Month, dtype: float64
# -----------------------

# %% [markdown]
# Now that we have cleaned our data we can move on to showing ROI for our movies

# %%
#In order to get to ROI I am  first making column with Profit
budgets['Profit'] = budgets['worldwide_gross'] - budgets['production_budget']

# %%
#checking to see our new column and sorting by profit
budgets.sort_values(by='Profit', ascending=False, inplace=True)

# %%
budgets.head()
# Out:
#    release_date                                 movie  production_budget  \
# 0    2009-12-18                                Avatar          425000000
# 42   1997-12-19                               Titanic          200000000
# 6    2018-04-27                Avengers: Infinity War          300000000
# 5    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 33   2015-06-12                        Jurassic World          215000000
#
#     domestic_gross  worldwide_gross  month Month      Profit
# 0        760507625       2776345279     12   Dec  2351345279
# 42       659363944       2208208395     12   Dec  2008208395
# 6        678815482       2048134200      4   Apr  1748134200
# 5        936662225       2053311220     12   Dec  1747311220
# 33       652270625       1648854864      6   Jun  1433854864

# %%
#Now to add a column for ROI
budgets['ROI'] = (budgets['Profit'] / budgets['production_budget']) * 100

# %%
#Sorting and viewing movies with top ROI
budgets = budgets.sort_values(by='ROI',ascending=False)

# %%
budgets.head()
# Out:
#      release_date                    movie  production_budget  domestic_gross  \
# 5745   1972-06-30              Deep Throat              25000        45000000
# 5613   1980-03-21                  Mad Max             200000         8750000
# 5492   2009-09-25      Paranormal Activity             450000       107918810
# 5679   2015-07-10              The Gallows             100000        22764410
# 5406   1999-07-14  The Blair Witch Project             600000       140539099
#
#       worldwide_gross  month Month     Profit            ROI
# 5745         45000000      6   Jun   44975000  179900.000000
# 5613         99750000      3   Mar   99550000   49775.000000
# 5492        194183034      9   Sep  193733034   43051.785333
# 5679         41656474      7   Jul   41556474   41556.474000
# 5406        248300000      7   Jul  247700000   41283.333333

# %% [markdown]
# Now we have ROI and Profit which is the key data we would like to solve for with other variables i.e Genres

# %%
#importing relevant data table with genre data, and resetting index so we have tconst as a column for later
genres = csv_files_dict['imdb_title_basics_gz']
genres.reset_index(inplace=True)

# %%
genres.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Renaming column we want to join on
genres.rename(columns={'primary_title' : 'movie'}, inplace=True)

# %%
#dfBG for dataframe Budget Genres
dfBG = budgets.set_index('movie').join(genres.set_index('movie'), how='left', on='movie')

# %%
dfBG.reset_index(inplace=True)

# %%
dfBG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7221 entries, 0 to 7220
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              7221 non-null   object
#  1   release_date       7221 non-null   datetime64[ns]
#  2   production_budget  7221 non-null   int64
#  3   domestic_gross     7221 non-null   int64
#  4   worldwide_gross    7221 non-null   int64
#  5   month              7221 non-null   int64
#  6   Month              7221 non-null   object
#  7   Profit             7221 non-null   int64
#  8   ROI                7221 non-null   float64
#  9   tconst             3815 non-null   object
#  10  original_title     3814 non-null   object
#  11  start_year         3815 non-null   float64
#  12  runtime_minutes    3328 non-null   float64
#  13  genres             3743 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(5)
# memory usage: 789.9+ KB

# %%
#48% of our rows for genre are missing but cannot do anything about the data we received at least for this project
dfBG.isna().sum()
# Out:
# movie                   0
# release_date            0
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# month                   0
# Month                   0
# Profit                  0
# ROI                     0
# tconst               3406
# original_title       3407
# start_year           3406
# runtime_minutes      3893
# genres               3478
# dtype: int64

# %%
#dropping na values as they dont have our ROI data
dfBG.dropna(inplace=True)

# %%
#checking
dfBG.isna().sum()
# Out:
# movie                0
# release_date         0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# month                0
# Month                0
# Profit               0
# ROI                  0
# tconst               0
# original_title       0
# start_year           0
# runtime_minutes      0
# genres               0
# dtype: int64

# %%
#checking for dupes
dfBG.movie.duplicated().sum()
# Out:
# 1106

# %%
#investigating dupes
dfBG[dfBG.movie.duplicated()]
# Out:
#                movie release_date  production_budget  domestic_gross  \
# 35        Cinderella   1950-02-15            2900000        85000000
# 36        Cinderella   1950-02-15            2900000        85000000
# 37        Cinderella   1950-02-15            2900000        85000000
# 38        Cinderella   1950-02-15            2900000        85000000
# 42              Home   2009-04-23             500000           15433
# ...              ...          ...                ...             ...
# 7174             Ten   2015-04-21              25000               0
# 7190   Irreplaceable   2015-02-24             600000               0
# 7191   Irreplaceable   2015-02-24             600000               0
# 7200  Treading Water   2015-03-10            4700000               0
# 7201  Treading Water   2015-03-10            4700000               0
#
#       worldwide_gross  month Month     Profit          ROI     tconst  \
# 35          263591415      2   Feb  260691415  8989.359138  tt1661199
# 36          263591415      2   Feb  260691415  8989.359138  tt3645784
# 37          263591415      2   Feb  260691415  8989.359138  tt5089556
# 38          263591415      2   Feb  260691415  8989.359138  tt5684194
# 42           44793168      4   Apr   44293168  8858.633600  tt2089701
# ...               ...    ...   ...        ...          ...        ...
# 7174                0      4   Apr     -25000  -100.000000  tt6415838
# 7190                0      2   Feb    -600000  -100.000000  tt5078326
# 7191                0      2   Feb    -600000  -100.000000  tt5274738
# 7200                0      3   Mar   -4700000  -100.000000  tt2891054
# 7201                0      3   Mar   -4700000  -100.000000  tt3210578
#
#            original_title  start_year  runtime_minutes  \
# 35             Cinderella      2015.0            105.0
# 36             Cinderella      2013.0            120.0
# 37             Cinderella      2015.0            113.0
# 38             Cinderella      2016.0            130.0
# 42                   Home      2011.0              7.0
# ...                   ...         ...              ...
# 7174                  Ten      2017.0             82.0
# 7190  Médecin de campagne      2016.0            102.0
# 7191        Irreplaceable      2015.0             61.0
# 7200       Treading Water      2013.0             24.0
# 7201       Treading Water      2013.0             98.0
#
#                              genres
# 35             Drama,Family,Fantasy
# 36                            Music
# 37                          Fantasy
# 38                          Musical
# 42         Documentary,Drama,Family
# ...                             ...
# 7174        Horror,Mystery,Thriller
# 7190                   Comedy,Drama
# 7191                          Drama
# 7200  Biography,Documentary,History
# 7201                          Drama
#
# [1106 rows x 14 columns]

# %%
#dropping duplicates below using subset release date as some movies indeed have multiple remakes 
dfBG.drop_duplicates(subset=['release_date', 'movie'], inplace=True)

# %%
#checking results
dfBG[dfBG.movie.duplicated(keep=False)].sort_values('movie', ascending=True).head()
# Out:
#                           movie release_date  production_budget  \
# 1980  A Nightmare on Elm Street   2010-04-30           35000000
# 327   A Nightmare on Elm Street   1984-11-09            1800000
# 254                     Aladdin   1992-11-11           28000000
# 1958                    Aladdin   2019-05-24          182000000
# 1206        Alice in Wonderland   2010-03-05          200000000
#
#       domestic_gross  worldwide_gross  month Month     Profit          ROI  \
# 1980        63075011        117729621      4   Apr   82729621   236.370346
# 327         25504513         25504513     11   Nov   23704513  1316.917389
# 254        217350219        504050219     11   Nov  476050219  1700.179354
# 1958       246734314        619234314      5   May  437234314   240.238634
# 1206       334191110       1025491110      3   Mar  825491110   412.745555
#
#          tconst             original_title  start_year  runtime_minutes  \
# 1980  tt1179056  A Nightmare on Elm Street      2010.0             95.0
# 327   tt1179056  A Nightmare on Elm Street      2010.0             95.0
# 254   tt6139732                    Aladdin      2019.0            128.0
# 1958  tt6139732                    Aladdin      2019.0            128.0
# 1206  tt1014759        Alice in Wonderland      2010.0            108.0
#
#                         genres
# 1980        Crime,Drama,Horror
# 327         Crime,Drama,Horror
# 254    Adventure,Comedy,Family
# 1958   Adventure,Comedy,Family
# 1206  Adventure,Family,Fantasy

# %%
dfBG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2264 entries, 3 to 7220
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              2264 non-null   object
#  1   release_date       2264 non-null   datetime64[ns]
#  2   production_budget  2264 non-null   int64
#  3   domestic_gross     2264 non-null   int64
#  4   worldwide_gross    2264 non-null   int64
#  5   month              2264 non-null   int64
#  6   Month              2264 non-null   object
#  7   Profit             2264 non-null   int64
#  8   ROI                2264 non-null   float64
#  9   tconst             2264 non-null   object
#  10  original_title     2264 non-null   object
#  11  start_year         2264 non-null   float64
#  12  runtime_minutes    2264 non-null   float64
#  13  genres             2264 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(5)
# memory usage: 265.3+ KB

# %%
#investigating our genres column and need to make into string, create a list, and then make columns with individual genres
dfBG.genres
# Out:
# 3       Horror,Mystery,Thriller
# 6         Biography,Documentary
# 8                        Horror
# 9           Action,Comedy,Drama
# 11              Horror,Thriller
#                  ...
# 7214       Drama,Romance,Sci-Fi
# 7217             Comedy,Romance
# 7218            Sci-Fi,Thriller
# 7219            Horror,Thriller
# 7220                   Thriller
# Name: genres, Length: 2264, dtype: object

# %%
#our lambda funciton is useful for this with split method creates our list
dfBG['genres_split'] = dfBG['genres'].map(lambda x: x.split(',') if x else x)
dfBG.head()
# Out:
#                        movie release_date  production_budget  domestic_gross  \
# 3                The Gallows   2015-07-10             100000        22764410
# 6                      Bambi   1942-08-13             858000       102797000
# 8   Night of the Living Dead   1968-10-01             114000        12087064
# 9                      Rocky   1976-11-21            1000000       117235147
# 11                 Halloween   1978-10-17             325000        47000000
#
#     worldwide_gross  month Month     Profit           ROI     tconst  \
# 3          41656474      7   Jul   41556474  41556.474000  tt2309260
# 6         268000000      8   Aug  267142000  31135.431235  tt2668120
# 8          30087064     10   Oct   29973064  26292.161404  tt3393372
# 9         225000000     11   Nov  224000000  22400.000000  tt3080284
# 11         70000000     10   Oct   69675000  21438.461538  tt1502407
#
#               original_title  start_year  runtime_minutes  \
# 3                The Gallows      2015.0             81.0
# 6                      Bambi      2013.0             58.0
# 8   Night of the Living Dead      2014.0             79.0
# 9                      Rocky      2013.0            136.0
# 11                 Halloween      2018.0            106.0
#
#                      genres                 genres_split
# 3   Horror,Mystery,Thriller  [Horror, Mystery, Thriller]
# 6     Biography,Documentary     [Biography, Documentary]
# 8                    Horror                     [Horror]
# 9       Action,Comedy,Drama      [Action, Comedy, Drama]
# 11          Horror,Thriller           [Horror, Thriller]

# %%
#resetting index since when we dropped dupes our index values no longer match our shape
dfBG.reset_index(inplace=True)

# %%
dfBG.drop('index',axis=1,inplace=True)

# %%
dfBG.head()
# Out:
#                       movie release_date  production_budget  domestic_gross  \
# 0               The Gallows   2015-07-10             100000        22764410
# 1                     Bambi   1942-08-13             858000       102797000
# 2  Night of the Living Dead   1968-10-01             114000        12087064
# 3                     Rocky   1976-11-21            1000000       117235147
# 4                 Halloween   1978-10-17             325000        47000000
#
#    worldwide_gross  month Month     Profit           ROI     tconst  \
# 0         41656474      7   Jul   41556474  41556.474000  tt2309260
# 1        268000000      8   Aug  267142000  31135.431235  tt2668120
# 2         30087064     10   Oct   29973064  26292.161404  tt3393372
# 3        225000000     11   Nov  224000000  22400.000000  tt3080284
# 4         70000000     10   Oct   69675000  21438.461538  tt1502407
#
#              original_title  start_year  runtime_minutes  \
# 0               The Gallows      2015.0             81.0
# 1                     Bambi      2013.0             58.0
# 2  Night of the Living Dead      2014.0             79.0
# 3                     Rocky      2013.0            136.0
# 4                 Halloween      2018.0            106.0
#
#                     genres                 genres_split
# 0  Horror,Mystery,Thriller  [Horror, Mystery, Thriller]
# 1    Biography,Documentary     [Biography, Documentary]
# 2                   Horror                     [Horror]
# 3      Action,Comedy,Drama      [Action, Comedy, Drama]
# 4          Horror,Thriller           [Horror, Thriller]

# %%
#below we are taking our list and creating a new column with first entry in that list
dfBG['genre1'] = dfBG['genres_split'].map(lambda x: x[0])

# %%
#checking our genres_split to make sure is indeed list
type(dfBG.genres_split[1])
# Out:
# list

# %%
#Checking value counts to see distribution, notice that family and below have few observations in our dataset
dfBG.genre1.value_counts()
# Out:
# Action         545
# Drama          477
# Comedy         410
# Adventure      199
# Biography      150
# Documentary    137
# Horror         135
# Crime          122
# Animation       22
# Thriller        22
# Sci-Fi          11
# Family           8
# Fantasy          7
# Mystery          6
# Romance          5
# Musical          4
# Music            2
# Western          1
# War              1
# Name: genre1, dtype: int64

# %%
#using our lambda function again here but create a variable to use as reference if movie only has 1 genre
y = 'NA'
dfBG['genre2'] = dfBG['genres_split'].map(lambda x: y if len(x) < 2 else x[1])

# %%
dfBG['genre3'] = dfBG['genres_split'].map(lambda x: y if len(x) < 3 else x[2])

# %%
#Great so now we have Genres separated and ROI time to plot
dfBG.head()
# Out:
#                       movie release_date  production_budget  domestic_gross  \
# 0               The Gallows   2015-07-10             100000        22764410
# 1                     Bambi   1942-08-13             858000       102797000
# 2  Night of the Living Dead   1968-10-01             114000        12087064
# 3                     Rocky   1976-11-21            1000000       117235147
# 4                 Halloween   1978-10-17             325000        47000000
#
#    worldwide_gross  month Month     Profit           ROI     tconst  \
# 0         41656474      7   Jul   41556474  41556.474000  tt2309260
# 1        268000000      8   Aug  267142000  31135.431235  tt2668120
# 2         30087064     10   Oct   29973064  26292.161404  tt3393372
# 3        225000000     11   Nov  224000000  22400.000000  tt3080284
# 4         70000000     10   Oct   69675000  21438.461538  tt1502407
#
#              original_title  start_year  runtime_minutes  \
# 0               The Gallows      2015.0             81.0
# 1                     Bambi      2013.0             58.0
# 2  Night of the Living Dead      2014.0             79.0
# 3                     Rocky      2013.0            136.0
# 4                 Halloween      2018.0            106.0
#
#                     genres                 genres_split     genre1  \
# 0  Horror,Mystery,Thriller  [Horror, Mystery, Thriller]     Horror
# 1    Biography,Documentary     [Biography, Documentary]  Biography
# 2                   Horror                     [Horror]     Horror
# 3      Action,Comedy,Drama      [Action, Comedy, Drama]     Action
# 4          Horror,Thriller           [Horror, Thriller]     Horror
#
#         genre2    genre3
# 0      Mystery  Thriller
# 1  Documentary        NA
# 2           NA        NA
# 3       Comedy     Drama
# 4     Thriller        NA

# %%
dfBG.drop(['original_title', 'start_year','genres', 'genres_split'], axis=1, inplace=True)

# %%
dfBG
# Out:
#                               movie release_date  production_budget  \
# 0                       The Gallows   2015-07-10             100000
# 1                             Bambi   1942-08-13             858000
# 2          Night of the Living Dead   1968-10-01             114000
# 3                             Rocky   1976-11-21            1000000
# 4                         Halloween   1978-10-17             325000
# ...                             ...          ...                ...
# 2259                           Womb   2012-03-30           13000000
# 2260      My Girlfriend's Boyfriend   2010-05-01            1400000
# 2261       All Superheroes Must Die   2013-01-04              20000
# 2262  House at the End of the Drive   2014-12-31            1400000
# 2263       Enter the Dangerous Mind   2015-02-06            3000000
#
#       domestic_gross  worldwide_gross  month Month     Profit           ROI  \
# 0           22764410         41656474      7   Jul   41556474  41556.474000
# 1          102797000        268000000      8   Aug  267142000  31135.431235
# 2           12087064         30087064     10   Oct   29973064  26292.161404
# 3          117235147        225000000     11   Nov  224000000  22400.000000
# 4           47000000         70000000     10   Oct   69675000  21438.461538
# ...              ...              ...    ...   ...        ...           ...
# 2259               0                0      3   Mar  -13000000   -100.000000
# 2260               0                0      5   May   -1400000   -100.000000
# 2261               0                0      1   Jan     -20000   -100.000000
# 2262               0                0     12   Dec   -1400000   -100.000000
# 2263               0                0      2   Feb   -3000000   -100.000000
#
#          tconst  runtime_minutes     genre1       genre2    genre3
# 0     tt2309260             81.0     Horror      Mystery  Thriller
# 1     tt2668120             58.0  Biography  Documentary        NA
# 2     tt3393372             79.0     Horror           NA        NA
# 3     tt3080284            136.0     Action       Comedy     Drama
# 4     tt1502407            106.0     Horror     Thriller        NA
# ...         ...              ...        ...          ...       ...
# 2259  tt1216520            111.0      Drama      Romance    Sci-Fi
# 2260  tt1447793             84.0     Comedy      Romance        NA
# 2261  tt1836212             78.0     Sci-Fi     Thriller        NA
# 2262  tt0464054             91.0     Horror     Thriller        NA
# 2263  tt2229377             88.0   Thriller           NA        NA
#
# [2264 rows x 14 columns]

# %%
#running boxplot to have an idea of preliminary data looks like
sns.boxplot(x ='ROI' , y = 'genre1', data=dfBG.sort_values(by='ROI', ascending=False), showfliers=False)
# Out:
# <AxesSubplot:xlabel='ROI', ylabel='genre1'>

# %%
#investigating why musical is so large of ROI, and because only 4 movies in population, but cinderalla a large outlier
dfBG.genre1.value_counts()
# Out:
# Action         545
# Drama          477
# Comedy         410
# Adventure      199
# Biography      150
# Documentary    137
# Horror         135
# Crime          122
# Animation       22
# Thriller        22
# Sci-Fi          11
# Family           8
# Fantasy          7
# Mystery          6
# Romance          5
# Musical          4
# Music            2
# Western          1
# War              1
# Name: genre1, dtype: int64

# %%
#We can see the original cinderalla was extremely successful, and heavily skews the ROI data for that genre 
dfBG[dfBG.genre1 == 'Musical']
# Out:
#                  movie release_date  production_budget  domestic_gross  \
# 9           Cinderella   1950-02-15            2900000        85000000
# 325         Cinderella   2015-03-13           95000000       201151353
# 1049      The Covenant   2006-09-08           20000000        23364784
# 1877  Standing Ovation   2010-07-16            5600000          531806
#
#       worldwide_gross  month Month     Profit          ROI      tconst  \
# 9           263591415      2   Feb  260691415  8989.359138  tt10013634
# 325         534551353      3   Mar  439551353   462.685635  tt10013634
# 1049         38164784      9   Sep   18164784    90.823920   tt3296724
# 1877           531806      7   Jul   -5068194   -90.503464   tt1303803
#
#       runtime_minutes   genre1 genre2 genre3
# 9               150.0  Musical     NA     NA
# 325             150.0  Musical     NA     NA
# 1049             99.0  Musical     NA     NA
# 1877            105.0  Musical     NA     NA

# %%
#For context there are only 10 movies in our entire data set that have an ROI greater than 8000%
dfBG[dfBG.ROI > 8000]
# Out:
#                               movie release_date  production_budget  \
# 0                       The Gallows   2015-07-10             100000
# 1                             Bambi   1942-08-13             858000
# 2          Night of the Living Dead   1968-10-01             114000
# 3                             Rocky   1976-11-21            1000000
# 4                         Halloween   1978-10-17             325000
# 5   Snow White and the Seven Dwarfs   1937-12-21            1488000
# 6                  The Devil Inside   2012-01-06            1000000
# 7             The Birth of a Nation   1915-02-08             110000
# 8                    Graduation Day   1981-05-01             250000
# 9                        Cinderella   1950-02-15            2900000
# 10                             Home   2009-04-23             500000
#
#     domestic_gross  worldwide_gross  month Month     Profit           ROI  \
# 0         22764410         41656474      7   Jul   41556474  41556.474000
# 1        102797000        268000000      8   Aug  267142000  31135.431235
# 2         12087064         30087064     10   Oct   29973064  26292.161404
# 3        117235147        225000000     11   Nov  224000000  22400.000000
# 4         47000000         70000000     10   Oct   69675000  21438.461538
# 5        184925486        184925486     12   Dec  183437486  12327.788038
# 6         53262945        101759490      1   Jan  100759490  10075.949000
# 7         10000000         11000000      2   Feb   10890000   9900.000000
# 8         23894000         23894000      5   May   23644000   9457.600000
# 9         85000000        263591415      2   Feb  260691415   8989.359138
# 10           15433         44793168      4   Apr   44293168   8858.633600
#
#         tconst  runtime_minutes     genre1       genre2    genre3
# 0    tt2309260             81.0     Horror      Mystery  Thriller
# 1    tt2668120             58.0  Biography  Documentary        NA
# 2    tt3393372             79.0     Horror           NA        NA
# 3    tt3080284            136.0     Action       Comedy     Drama
# 4    tt1502407            106.0     Horror     Thriller        NA
# 5    tt7821084             49.0  Animation       Family        NA
# 6    tt1560985             83.0     Horror           NA        NA
# 7    tt4196450            120.0  Biography        Drama   History
# 8    tt2616818             75.0   Thriller           NA        NA
# 9   tt10013634            150.0    Musical           NA        NA
# 10   tt2075392             76.0      Drama           NA        NA

# %%
#create new df with groupby for genres aggregated by median and count
#resetting the index to reference genres for our plot
# and checking our new df
genrestats = dfBG.groupby(by='genre1').agg(['median','mean', 'count'])
genrestats.reset_index(inplace=True)
genrestats.head()
# Out:
#       genre1 production_budget                     domestic_gross  \
#                         median          mean count         median
# 0     Action          42500000  7.014503e+07   545     38362475.0
# 1  Adventure          50000000  6.884572e+07   199     55483770.0
# 2  Animation          28500000  4.148987e+07    22     28010636.5
# 3  Biography          17000000  2.212839e+07   150     15613098.5
# 4     Comedy          12000000  2.040214e+07   410     16416490.5
#
#                       worldwide_gross                      ... month  \
#            mean count          median          mean count  ... count
# 0  7.707130e+07   545      90815558.0  2.086961e+08   545  ...   545
# 1  8.452708e+07   199     115149422.0  2.318463e+08   199  ...   199
# 2  8.094487e+07    22      45378743.0  1.795110e+08    22  ...    22
# 3  3.229156e+07   150      25724122.0  6.509016e+07   150  ...   150
# 4  3.200412e+07   410      23451168.0  5.884439e+07   410  ...   410
#
#        Profit                             ROI                    \
#        median          mean count      median        mean count
# 0  41647574.0  1.385511e+08   545  103.195366  213.169369   545
# 1  51946251.0  1.630006e+08   199  137.240837  204.744769   199
# 2  16810363.0  1.380211e+08    22   86.156057  866.380154    22
# 3  10186029.5  4.296178e+07   150   83.196940  486.263409   150
# 4   9722533.0  3.844225e+07   410   73.617544  206.392024   410
#
#   runtime_minutes
#            median        mean count
# 0           108.0  110.431193   545
# 1            98.0   99.256281   199
# 2            87.0   85.181818    22
# 3           112.0  108.613333   150
# 4            99.5  100.321951   410
#
# [5 rows x 22 columns]

# %%
#most importantly here we are filtering out the genres with less than 10 observations as they dont have enough data
#for us to make a conclusion about that genre and to minimize the skew in our data i.e. musicals
genrestats1 = genrestats[genrestats['production_budget']['count'] >10]

# %%
#Both plots below are sorted by ROI descending. The left plot show median ROI of each Genre, while the  
#right plot shows production budget of each genre

plt.figure(figsize=(20,10))
sns.set(font_scale = 1.5)
sns.set_style("white")
ax1 = plt.subplot(1,2,1)
ax1 = sns.barplot(x=('ROI','median'), y=('genre1'), data=genrestats1.sort_values(('ROI','median'), ascending=False),
            palette='Greens_r').set(ylabel='Genres', xlabel=('Return on Investment'), title=("Return on Investment by Genre"))

ax2 = plt.subplot(1,2,2)
ax2 = sns.barplot(x=('production_budget','median'), y=('genre1'), data=genrestats1.sort_values(('ROI','median'), ascending=False),
            palette='Blues_r').set(ylabel='Genres', xlabel=('Production Budget'), title=("Production Budget by Genre"), )


plt.subplots_adjust(wspace=.4)


#(*To note this does not include the genres we dropped with less than 10 data points where otherwise)
#(*the musical genre would have been amongst the top genres as well)

# %% [markdown]
# Firstly, we can see that the top 5 genres by ROI (left-plot) are Adventure, Horror, Sci-Fi, Action, and Animation
# Secondly, and more importantly is that among the top 5 genres by ROI, Horror had the smallest budget yet still yielded the second highest ROI of the genres in our data set
#
# In conclusion, on a purely profitability basis, I would suggest that MSFT make a movie in one of the top 5 genres mentioned.
# If budget constraints are a material factor in this decision, horror movies would require the least amount of investment.

# %% [markdown]
# # 2. Which month(s) will yield the best result for a film?
#     -Explore the relationship of film release dates and audience participation
#     -Investigate which months have had most success in terms of gross revenue
#     -Investigate whether a film's budget should influence it's release date

# %%
#importing file with popularity and vote information (2 versions 1 for investigating on its own and other for merge)
tmdb_movies = csv_files_dict['tmdb_movies_gz']
tmdb_movies1 = csv_files_dict['tmdb_movies_gz']
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#no missing values
tmdb_movies.isna().sum()
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
import calendar
tmdb_movies['release_date'] = pd.to_datetime(tmdb_movies.release_date).sort_values(axis=0, ascending=False)
tmdb_movies['month'] = pd.DatetimeIndex(tmdb_movies.release_date).month
tmdb_movies['Month'] = tmdb_movies['month'].apply(lambda x: calendar.month_abbr[x])

# %%
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
#
#    month Month
# 0     11   Nov
# 1      3   Mar
# 2      5   May
# 3     11   Nov
# 4      7   Jul

# %%
tmdb_movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count         month
# count   26517.000000  26517.000000  26517.000000  26517.000000  26517.000000
# mean   295050.153260      3.130912      5.991281    194.224837      6.405966
# std    153661.615648      4.355229      1.852946    960.961095      3.573796
# min        27.000000      0.600000      0.000000      1.000000      1.000000
# 25%    157851.000000      0.600000      5.000000      2.000000      3.000000
# 50%    309581.000000      1.374000      6.000000      5.000000      6.000000
# 75%    419542.000000      3.694000      7.000000     28.000000     10.000000
# max    608444.000000     80.773000     10.000000  22186.000000     12.000000

# %%
#popularity has ~25% values of.6 but vote count alos has around the same of vote count of 1,
#is logical that if a movie has only 1 vote count it is not popular
for col in tmdb_movies:
    print(f"Currently checking values from col: {col}")
    print(f"Top 5 values:\n{tmdb_movies[col].value_counts(normalize=True)[:7]}")
    print('-----------------------')
# Out:
# Currently checking values from col: genre_ids
# Top 5 values:
# [99]        0.139533
# []          0.093487
# [18]        0.085530
# [35]        0.062601
# [27]        0.043180
# [53]        0.018102
# [35, 18]    0.017574
# Name: genre_ids, dtype: float64
# -----------------------
# Currently checking values from col: id
# Top 5 values:
# 292086    0.000113
# 463839    0.000113
# 11976     0.000113
# 391872    0.000113
# 416572    0.000113
# 121803    0.000113
# 192023    0.000113
# Name: id, dtype: float64
# -----------------------
# Currently checking values from col: original_language
# Top 5 values:
# en    0.878342
# fr    0.019120
# es    0.017159
# ru    0.011238
# ja    0.009994
# de    0.008938
# zh    0.006675
# Name: original_language, dtype: float64
# -----------------------
# Currently checking values from col: original_title
# Top 5 values:
# Eden             0.000264
# Home             0.000226
# Truth or Dare    0.000189
# Lucky            0.000189
# Legend           0.000189
# Aftermath        0.000189
# Solace           0.000151
# Name: original_title, dtype: float64
# -----------------------
# Currently checking values from col: popularity
# Top 5 values:
# 0.600     0.265377
# 1.400     0.024475
# 0.840     0.022137
# 0.624     0.003922
# 0.625     0.003469
#             ...
# 3.135     0.000038
# 8.384     0.000038
# 1.486     0.000038
# 10.962    0.000038
# 7.000     0.000038
# Name: popularity, Length: 6395, dtype: float64
# -----------------------
# Currently checking values from col: release_date
# Top 5 values:
# 2010-01-01    0.010144
# 2011-01-01    0.007542
# 2014-01-01    0.005845
# 2012-01-01    0.005845
# 2013-01-01    0.005468
# 2015-01-01    0.003658
# 2011-11-11    0.002753
# Name: release_date, dtype: float64
# -----------------------
# Currently checking values from col: title
# Top 5 values:
# Eden             0.000264
# Home             0.000264
# Aftermath        0.000189
# Legend           0.000189
# The Gift         0.000189
# Truth or Dare    0.000189
# Lucky            0.000189
# Name: title, dtype: float64
# -----------------------
# Currently checking values from col: vote_average
# Top 5 values:
# 6.0    0.073161
# 7.0    0.058830
# Name: vote_average, dtype: float64
# -----------------------
# Currently checking values from col: vote_count
# Top 5 values:
# 1    0.246672
# 2    0.114794
# 3    0.066259
# 4    0.050798
# 5    0.036543
# 6    0.030094
# 7    0.024513
# Name: vote_count, dtype: float64
# -----------------------
# Currently checking values from col: month
# Top 5 values:
# 1     0.118113
# 10    0.114455
# 4     0.096768
# 3     0.090734
# 11    0.088170
# 9     0.085379
# 6     0.081683
# Name: month, dtype: float64
# -----------------------
# Currently checking values from col: Month
# Top 5 values:
# Jan    0.118113
# Oct    0.114455
# Apr    0.096768
# Mar    0.090734
# Nov    0.088170
# Sep    0.085379
# Jun    0.081683
# Name: Month, dtype: float64
# -----------------------

# %%
tmdb_movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count         month
# count   26517.000000  26517.000000  26517.000000  26517.000000  26517.000000
# mean   295050.153260      3.130912      5.991281    194.224837      6.405966
# std    153661.615648      4.355229      1.852946    960.961095      3.573796
# min        27.000000      0.600000      0.000000      1.000000      1.000000
# 25%    157851.000000      0.600000      5.000000      2.000000      3.000000
# 50%    309581.000000      1.374000      6.000000      5.000000      6.000000
# 75%    419542.000000      3.694000      7.000000     28.000000     10.000000
# max    608444.000000     80.773000     10.000000  22186.000000     12.000000

# %%
tmdbgroupmonth = tmdb_movies.groupby('Month').median()

# %%
tmdbgroupmonth.sort_values('month')
# Out:
#              id  popularity  vote_average  vote_count  month
# Month
# Jan    310154.0      0.8830           6.0         3.0    1.0
# Feb    314210.0      1.5130           6.0         6.0    2.0
# Mar    309024.0      1.4000           6.0         5.0    3.0
# Apr    322519.0      1.2410           6.1         5.0    4.0
# May    307087.0      1.3470           6.0         5.0    5.0
# Jun    307977.5      1.3565           6.0         5.0    6.0
# Jul    298842.5      1.4000           6.0         6.0    7.0
# Aug    301204.5      1.6020           6.0         6.0    8.0
# Sep    299326.0      1.4000           6.0         6.0    9.0
# Oct    316000.0      1.4000           6.0         5.0   10.0
# Nov    302927.0      1.4000           6.2         6.0   11.0
# Dec    318553.0      1.5480           6.1         7.0   12.0

# %%
#observe that movies with highest vote rating are in April, Nov, Jun which not implied by our revenue data
sns.lineplot(x='Month', y='popularity', data=tmdbgroupmonth.sort_values('month'), color='Orange')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='popularity'>

# %%
#looking at vote count by month we see that audience participation is highest in Dec, Nov, Jul
#assuming higher vote count infers higher participation implicitly  
sns.set_style('white')
sns.lineplot(x='Month', y='vote_count', data=tmdbgroupmonth.sort_values('month'), color='Orange')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='vote_count'>

# %%
#plotting average count by month vs gross revenues
plt.figure(figsize=(12,6))
sns.set(font_scale = 1.5)
sns.set_style("whitegrid")
ax1 = plt.subplot(1,2,1)
ax1 = sns.lineplot(x='Month', y='vote_count', data=tmdb_movies.sort_values('month'), color='Red',
                   marker='o', ci=False).set(ylabel='Average Vote Count', xlabel=('Month'), title=("Average Vote Count by Month"), )
plt.xticks(rotation=45)

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(x='Month', y='ROI', data=monthgroup.sort_values('month'), color='Green', 
                   marker='o').set(ylabel="'Worldwide Gross Revenue (mm's)", xlabel=('Month'), title=("Worldwide Gross Revenue by Month") )
plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: int(x/1000000)))

plt.subplots_adjust(wspace=.4)

# %%
budgets.describe(percentiles=[.5,.95])
# Out:
#        production_budget  domestic_gross  worldwide_gross        month  \
# count       5.782000e+03    5.782000e+03     5.782000e+03  5782.000000
# mean        3.158776e+07    4.187333e+07     9.148746e+07     7.050675
# std         4.181208e+07    6.824060e+07     1.747200e+08     3.480147
# min         1.100000e+03    0.000000e+00     0.000000e+00     1.000000
# 50%         1.700000e+07    1.722594e+07     2.798445e+07     7.000000
# 95%         1.200000e+08    1.695953e+08     3.874767e+08    12.000000
# max         4.250000e+08    9.366622e+08     2.776345e+09    12.000000
#
#              Profit            ROI
# count  5.782000e+03    5782.000000
# mean   5.989970e+07     380.016137
# std    1.460889e+08    2953.028231
# min   -2.002376e+08    -100.000000
# 50%    8.550286e+06      70.830983
# 95%    3.047441e+08    1167.448271
# max    2.351345e+09  179900.000000

# %%
pd.set_option('max_columns', None,'max_rows', None)

# %%
largemovies = budgets[budgets.production_budget > 75000000]

# %%
sns.lineplot(y='production_budget', x='Month', 
             data=largemovies.sort_values('month'), color='Blue',
             ci=False).set(ylabel='Production Budget', title='Blockbuster Movie Release by Month' )

plt.xticks(rotation=45)

# %% [markdown]
# As we can see be the plots here, viewer participation is highest end of year in November and December followed by the summer month July, May and June, which is aligned to the months with the highest ROI. I would suggest that MSFT consider releasing in

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 1.5)
sns.set_style("white")
ax1 = plt.subplot(1,2,1)
ax1 = sns.lineplot(x='Month', y='vote', data=tmdbgroupmonth.sort_values('month'), color='Orange')

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(x='Month', y='ROI', data=monthgroup.sort_values('month'))

plt.subplots_adjust(wspace=.4)

# %%
sns.lineplot(x='Month', y='worldwide_gross', data=budgets.sort_values('month'))
# Out:
# <AxesSubplot:xlabel='Month', ylabel='worldwide_gross'>

# %%
budgets.describe()

# %%
budgets[budgets.production_budget > 40000000]
# Out:
#      release_date                   movie  production_budget  domestic_gross  \
# 824    1993-06-11           Jurassic Park           63000000       395708305
# 983    2018-11-02       Bohemian Rhapsody           55000000       216303339
# 672    2015-07-10                 Minions           74000000       336045770
# 955    2016-02-12                Deadpool           58000000       363070709
# 629    2017-06-30         Despicable Me 3           75000000       264624300
# ...           ...                     ...                ...             ...
# 535    2020-02-21        Call of the Wild           82000000               0
# 1207   2019-11-22      The Rhythm Section           50000000               0
# 1206   2019-11-08             Arctic Dogs           50000000               0
# 1205   2020-12-31  Hannibal the Conqueror           50000000               0
# 1208   2019-09-20                Ad Astra           49800000               0
#
#       worldwide_gross  month Month      Profit          ROI
# 824        1038812584      6   Jun   975812584  1548.908863
# 983         894985342     11   Nov   839985342  1527.246076
# 672        1160336173      7   Jul  1086336173  1468.021855
# 955         801025593      2   Feb   743025593  1281.078609
# 629        1034727750      6   Jun   959727750  1279.637000
# ...               ...    ...   ...         ...          ...
# 535                 0      2   Feb   -82000000  -100.000000
# 1207                0     11   Nov   -50000000  -100.000000
# 1206                0     11   Nov   -50000000  -100.000000
# 1205                0     12   Dec   -50000000  -100.000000
# 1208                0      9   Sep   -49800000  -100.000000
#
# [1374 rows x 9 columns]

# %%
dfBM = pd.merge(budgets, tmdb_movies1, left_on='movie',right_on='title', how='left')
dfBM.isna().sum()
# Out:
# release_date_x          0
# movie                   0
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# month                   0
# Month                   0
# Profit                  0
# ROI                     0
# genre_ids            3805
# id                   3805
# original_language    3805
# original_title       3805
# popularity           3805
# release_date_y       3805
# title                3805
# vote_average         3805
# vote_count           3805
# dtype: int64

# %%
dfBM.dropna(inplace=True)

# %%
dfBM[dfBM.movie.duplicated()].sort_values('movie').head()
# Out:
#      release_date_x                      movie  production_budget  \
# 1242     2017-11-01       A Bad Moms Christmas           28000000
# 5120     2011-06-24              A Better Life           10000000
# 3834     2017-01-06            A Monster Calls           43000000
# 4704     2014-12-31        A Most Violent Year           20000000
# 1783     2010-04-30  A Nightmare on Elm Street           35000000
#
#       domestic_gross  worldwide_gross  month Month    Profit         ROI  \
# 1242        72110659        127710550     11   Nov  99710550  356.109107
# 5120         1759252          1884251      6   Jun  -8115749  -81.157490
# 3834         3740823         46414530      1   Jan   3414530    7.940767
# 4704         5749134          8846875     12   Dec -11153125  -55.765625
# 1783        63075011        117729621      4   Apr  82729621  236.370346
#
#            genre_ids        id original_language             original_title  \
# 1242            [35]  431530.0                en       A Bad Moms Christmas
# 5120            [99]  418293.0                en              A Better Life
# 3834        [18, 14]  258230.0                en            A Monster Calls
# 4704    [80, 18, 53]  241239.0                en        A Most Violent Year
# 1783  [27, 9648, 53]   23437.0                en  A Nightmare on Elm Street
#
#       popularity release_date_y                      title  vote_average  \
# 1242      16.604     2017-11-01       A Bad Moms Christmas           6.3
# 5120       0.600     2015-05-01              A Better Life          10.0
# 3834      11.128     2016-12-23            A Monster Calls           7.1
# 4704      12.271     2014-12-31        A Most Violent Year           6.6
# 1783       9.795     2010-04-30  A Nightmare on Elm Street           5.5
#
#       vote_count
# 1242      1044.0
# 5120         1.0
# 3834      1918.0
# 4704       792.0
# 1783      1408.0

# %%
dfBM.drop_duplicates(subset=['release_date_x', 'movie'], inplace=True)

# %%
#unfortunately less data here than other merge, will only use this to compare ROI and average rating counts etc
dfBM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977 entries, 3 to 6189
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date_x     1977 non-null   datetime64[ns]
#  1   movie              1977 non-null   object
#  2   production_budget  1977 non-null   int64
#  3   domestic_gross     1977 non-null   int64
#  4   worldwide_gross    1977 non-null   int64
#  5   month              1977 non-null   int64
#  6   Month              1977 non-null   object
#  7   Profit             1977 non-null   int64
#  8   ROI                1977 non-null   float64
#  9   genre_ids          1977 non-null   object
#  10  id                 1977 non-null   float64
#  11  original_language  1977 non-null   object
#  12  original_title     1977 non-null   object
#  13  popularity         1977 non-null   float64
#  14  release_date_y     1977 non-null   object
#  15  title              1977 non-null   object
#  16  vote_average       1977 non-null   float64
#  17  vote_count         1977 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(5), object(7)
# memory usage: 293.5+ KB

# %%
sns.lin

# %%
a = budgets.drop('movie',axis=1).sort_values('month')

# %%
#Creating budgets grouped by month
monthgroup = a.groupby('Month').median()

# %%
monthgroup = monthgroup.sort_values('month')

# %%
monthgroup= monthgroup.reset_index().set_index('month')

# %%
monthgroup
# Out:
#       Month  production_budget  domestic_gross  worldwide_gross      Profit  \
# month
# 1.0     Jan         14000000.0      14218868.0       20169934.0   5322212.0
# 2.0     Feb         17250000.0      19096003.0       33097834.5  10443556.0
# 3.0     Mar         15000000.0      15303247.5       25599836.0   7811580.5
# 4.0     Apr         15000000.0      12222522.5       20068010.0   4639885.0
# 5.0     May         16000000.0      19894664.0       29934477.0  13609577.0
# 6.0     Jun         21000000.0      33644788.0       46844357.0  21129194.0
# 7.0     Jul         21000000.0      31803006.5       51134699.5  21117855.5
# 8.0     Aug         16000000.0      16142205.0       24202936.5   6972068.5
# 9.0     Sep         15000000.0      10725228.0       18535575.0   1410835.0
# 10.0    Oct         12000000.0      11092559.0       16628751.0   3271253.0
# 11.0    Nov         24000000.0      30903239.0       50530475.5  23241650.5
# 12.0    Dec         19400000.0      16235738.0       31166312.0   7836366.0
#
#               ROI
# month
# 1.0     51.205360
# 2.0     74.028042
# 3.0     53.132902
# 4.0     39.986575
# 5.0    107.574875
# 6.0    125.211044
# 7.0    124.406717
# 8.0     68.287363
# 9.0     30.089300
# 10.0    44.103175
# 11.0   116.835489
# 12.0    62.880503

# %%
#Below we plot Worldwide Revenues and production budget together to see how they vary by month
plt.figure(figsize=(10,6))
sns.set(font_scale = 1.5)
sns.set_style("whitegrid")


fx = sns.lineplot(x='Month', y='worldwide_gross', data=monthgroup.sort_values('month'), marker='o', legend='brief', label='Worldwide Revenue')
fx1 = sns.lineplot(x='Month', y='production_budget', data=monthgroup.sort_values('month'), marker='o', legend='brief', label='Production Budget')
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: int(x/1000000)))
plt.xlabel('Month')
plt.ylabel('Millions')
plt.title('Worldwide Revenue and Production Budget by Month')


plt.show()

# %% [markdown]
# From our graph above here we can see the highest revenue months are July, November, and June

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 1.5)
sns.set_style("white")
ax1 = plt.subplot(2,1,1)
ax1 = sns.lineplot(x='Month', y='worldwide_gross', data=budgets.sort_values('month'),
                  color='Green').set(ylabel='Worldwide Gross Revenue', 
                                         xlabel=('Movie Release Month'), title=("Worldwide Revenue by Month"))

ax2 = plt.subplot(2,1,2)
ax2 = sns.lineplot(x='Month', y='production_budget', data=budgets.sort_values('month'),
                  color='Orange').set(ylabel='Production Budget', 
                                         xlabel=('Movie Release Month'), title=("Production Budget by Month"))

plt.tight_layout()
plt.subplots_adjust(wspace=1)

# %% [markdown]
# Notes:
# Budgets, title_basic, crew (for directors), title_prin for nconst, name_basics

# %%
['data/zippedData\\bom.movie_gross.csv.gz',
 'data/zippedData\\imdb.name.basics.csv.gz',
 'data/zippedData\\imdb.title.akas.csv.gz',
 'data/zippedData\\imdb.title.basics.csv.gz',
 'data/zippedData\\imdb.title.crew.csv.gz',
 'data/zippedData\\imdb.title.principals.csv.gz',
 'data/zippedData\\imdb.title.ratings.csv.gz',
 'data/zippedData\\tmdb.movies.csv.gz',
 'data/zippedData\\tn.movie_budgets.csv.gz']

# %%
#Fortunate for us we already have a table with tconst, so now all we need to do is join in crew, title_prin, and name_basics

# %%
crew = csv_files_dict['imdb_title_crew_gz']

# %%
crew
# Out:
#                                directors              writers
# tconst
# tt0285252                      nm0899854            nm0899854
# tt0438973                            NaN  nm0175726,nm1802864
# tt0462036                      nm1940585            nm1940585
# tt0835418                      nm0151540  nm0310087,nm0841532
# tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...                                  ...                  ...
# tt8999974                     nm10122357           nm10122357
# tt9001390                      nm6711477            nm6711477
# tt9001494          nm10123242,nm10123248                  NaN
# tt9004986                      nm4993825            nm4993825
# tt9010172                            NaN            nm8352242
#
# [146144 rows x 2 columns]

# %%
crew.reset_index(inplace=True)

# %%
crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
dfBGC = pd.merge(dfBG, crew, left_on='tconst',right_on='tconst', how='left')

# %%
BC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2264 entries, 0 to 2263
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              2264 non-null   object
#  1   release_date       2264 non-null   datetime64[ns]
#  2   production_budget  2264 non-null   int64
#  3   domestic_gross     2264 non-null   int64
#  4   worldwide_gross    2264 non-null   int64
#  5   month              2264 non-null   int64
#  6   Month              2264 non-null   object
#  7   Profit             2264 non-null   int64
#  8   ROI                2264 non-null   float64
#  9   tconst             2264 non-null   object
#  10  runtime_minutes    2264 non-null   float64
#  11  genre1             2264 non-null   object
#  12  genre2             2264 non-null   object
#  13  genre3             2264 non-null   object
#  14  directors          2258 non-null   object
#  15  writers            2138 non-null   object
#  16  director_split     2264 non-null   object
#  17  director1          2264 non-null   object
#  18  director2          2264 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(11)
# memory usage: 353.8+ KB

# %%
dfBGC.directors.str.split()
# Out:
# 0       [nm4000389,nm3951039]
# 1                 [nm0509852]
# 2                 [nm5209991]
# 3                 [nm1126847]
# 4                 [nm0337773]
#                 ...
# 2259              [nm1212903]
# 2260              [nm1111123]
# 2261              [nm1875808]
# 2262              [nm0175730]
# 2263    [nm1226077,nm0216459]
# Name: directors, Length: 2264, dtype: object

# %%
#splitting directors into list then individual column to join on nconst

# %%
dfBGC['director_split'] = BC['directors'].map(lambda x: str(x).split(',') if x else x)

# %%
dfBGC['director1'] = BC['director_split'].map(lambda x: x[0])

# %%
dfBGC['director2'] = BC['director_split'].map(lambda x: y if len(x) < 2 else x[1])

# %%
testgroupx
# Out:
#        production_budget  worldwide_gross  month    Profit         ROI
# Month
# Jan             14000000         20169934    1.0   5322212   51.205360
# Feb             17250000         33097834    2.0  10443556   74.028042
# Mar             15000000         25599836    3.0   7811580   53.132902
# Apr             15000000         20068010    4.0   4639885   39.986575
# May             16000000         29934477    5.0  13609577  107.574875
# Jun             21000000         46844357    6.0  21129194  125.211044
# Jul             21000000         51134699    7.0  21117855  124.406717
# Aug             16000000         24202936    8.0   6972068   68.287363
# Sep             15000000         18535575    9.0   1410835   30.089300
# Oct             12000000         16628751   10.0   3271253   44.103175
# Nov             24000000         50530475   11.0  23241650  116.835489
# Dec             19400000         31166312   12.0   7836366   62.880503

# %%
budgets.head()
# Out:
#      release_date                    movie  production_budget  domestic_gross  \
# 5745   1972-06-30              Deep Throat              25000        45000000
# 5613   1980-03-21                  Mad Max             200000         8750000
# 5492   2009-09-25      Paranormal Activity             450000       107918810
# 5679   2015-07-10              The Gallows             100000        22764410
# 5406   1999-07-14  The Blair Witch Project             600000       140539099
#
#       worldwide_gross  month Month     Profit            ROI
# 5745         45000000      6   Jun   44975000  179900.000000
# 5613         99750000      3   Mar   99550000   49775.000000
# 5492        194183034      9   Sep  193733034   43051.785333
# 5679         41656474      7   Jul   41556474   41556.474000
# 5406        248300000      7   Jul  247700000   41283.333333

# %%
dfBGC
# Out:
#                               movie release_date  production_budget  \
# 0                       The Gallows   2015-07-10             100000
# 1                             Bambi   1942-08-13             858000
# 2          Night of the Living Dead   1968-10-01             114000
# 3                             Rocky   1976-11-21            1000000
# 4                         Halloween   1978-10-17             325000
# ...                             ...          ...                ...
# 2259                           Womb   2012-03-30           13000000
# 2260      My Girlfriend's Boyfriend   2010-05-01            1400000
# 2261       All Superheroes Must Die   2013-01-04              20000
# 2262  House at the End of the Drive   2014-12-31            1400000
# 2263       Enter the Dangerous Mind   2015-02-06            3000000
#
#       domestic_gross  worldwide_gross  month Month     Profit           ROI  \
# 0           22764410         41656474      7   Jul   41556474  41556.474000
# 1          102797000        268000000      8   Aug  267142000  31135.431235
# 2           12087064         30087064     10   Oct   29973064  26292.161404
# 3          117235147        225000000     11   Nov  224000000  22400.000000
# 4           47000000         70000000     10   Oct   69675000  21438.461538
# ...              ...              ...    ...   ...        ...           ...
# 2259               0                0      3   Mar  -13000000   -100.000000
# 2260               0                0      5   May   -1400000   -100.000000
# 2261               0                0      1   Jan     -20000   -100.000000
# 2262               0                0     12   Dec   -1400000   -100.000000
# 2263               0                0      2   Feb   -3000000   -100.000000
#
#          tconst  runtime_minutes     genre1       genre2    genre3  \
# 0     tt2309260             81.0     Horror      Mystery  Thriller
# 1     tt2668120             58.0  Biography  Documentary        NA
# 2     tt3393372             79.0     Horror           NA        NA
# 3     tt3080284            136.0     Action       Comedy     Drama
# 4     tt1502407            106.0     Horror     Thriller        NA
# ...         ...              ...        ...          ...       ...
# 2259  tt1216520            111.0      Drama      Romance    Sci-Fi
# 2260  tt1447793             84.0     Comedy      Romance        NA
# 2261  tt1836212             78.0     Sci-Fi     Thriller        NA
# 2262  tt0464054             91.0     Horror     Thriller        NA
# 2263  tt2229377             88.0   Thriller           NA        NA
#
#                 directors                                            writers  \
# 0     nm4000389,nm3951039                                nm3951039,nm4000389
# 1               nm0509852                                          nm0509852
# 2               nm5209991                                          nm5209991
# 3               nm1126847                                                NaN
# 4               nm0337773  nm0000118,nm0384185,nm2171769,nm1144419,nm0337773
# ...                   ...                                                ...
# 2259            nm1212903                                          nm1212903
# 2260            nm1111123                                nm1111123,nm2109194
# 2261            nm1875808                                          nm1875808
# 2262            nm0175730                                nm0003905,nm1952191
# 2263  nm1226077,nm0216459                                          nm1226077
#
#               director_split  director1  director2
# 0     [nm4000389, nm3951039]  nm4000389  nm3951039
# 1                [nm0509852]  nm0509852         NA
# 2                [nm5209991]  nm5209991         NA
# 3                [nm1126847]  nm1126847         NA
# 4                [nm0337773]  nm0337773         NA
# ...                      ...        ...        ...
# 2259             [nm1212903]  nm1212903         NA
# 2260             [nm1111123]  nm1111123         NA
# 2261             [nm1875808]  nm1875808         NA
# 2262             [nm0175730]  nm0175730         NA
# 2263  [nm1226077, nm0216459]  nm1226077  nm0216459
#
# [2264 rows x 19 columns]

# %%
names = csv_files_dict['imdb_name_basics_gz']
names.head()
# Out:
#                 primary_name  birth_year  death_year  \
# nconst
# nm0061671  Mary Ellen Bauder         NaN         NaN
# nm0061865       Joseph Bauer         NaN         NaN
# nm0062070         Bruce Baum         NaN         NaN
# nm0062195       Axel Baumann         NaN         NaN
# nm0062798        Pete Baxter         NaN         NaN
#
#                                          primary_profession  \
# nconst
# nm0061671         miscellaneous,production_manager,producer
# nm0061865        composer,music_department,sound_department
# nm0062070                        miscellaneous,actor,writer
# nm0062195  camera_department,cinematographer,art_department
# nm0062798  production_designer,art_department,set_decorator
#
#                                   known_for_titles
# nconst
# nm0061671  tt0837562,tt2398241,tt0844471,tt0118553
# nm0061865  tt0896534,tt6791238,tt0287072,tt1682940
# nm0062070  tt1470654,tt0363631,tt0104030,tt0102898
# nm0062195  tt0114371,tt2004304,tt1618448,tt1224387
# nm0062798  tt0452644,tt0452692,tt3458030,tt2178256

# %%
BCN = pd.merge(dfBGC, names, left_on='director1', right_on='nconst', how='left')
BCN.head()
# Out:
#                       movie release_date  production_budget  domestic_gross  \
# 0               The Gallows   2015-07-10             100000        22764410
# 1                     Bambi   1942-08-13             858000       102797000
# 2  Night of the Living Dead   1968-10-01             114000        12087064
# 3                     Rocky   1976-11-21            1000000       117235147
# 4                 Halloween   1978-10-17             325000        47000000
#
#    worldwide_gross  month Month     Profit           ROI     tconst  ...  \
# 0         41656474      7   Jul   41556474  41556.474000  tt2309260  ...
# 1        268000000      8   Aug  267142000  31135.431235  tt2668120  ...
# 2         30087064     10   Oct   29973064  26292.161404  tt3393372  ...
# 3        225000000     11   Nov  224000000  22400.000000  tt3080284  ...
# 4         70000000     10   Oct   69675000  21438.461538  tt1502407  ...
#
#              directors                                            writers  \
# 0  nm4000389,nm3951039                                nm3951039,nm4000389
# 1            nm0509852                                          nm0509852
# 2            nm5209991                                          nm5209991
# 3            nm1126847                                                NaN
# 4            nm0337773  nm0000118,nm0384185,nm2171769,nm1144419,nm0337773
#
#            director_split  director1  director2        primary_name  \
# 0  [nm4000389, nm3951039]  nm4000389  nm3951039        Travis Cluff
# 1             [nm0509852]  nm0509852         NA  Sébastien Lifshitz
# 2             [nm5209991]  nm5209991         NA          Chad Zuver
# 3             [nm1126847]  nm1126847         NA        Sujit Mondal
# 4             [nm0337773]  nm0337773         NA  David Gordon Green
#
#   birth_year death_year                  primary_profession  \
# 0        NaN        NaN             producer,actor,director
# 1     1968.0        NaN               director,writer,actor
# 2        NaN        NaN               producer,actor,writer
# 3        NaN        NaN  assistant_director,director,writer
# 4     1975.0        NaN            producer,director,writer
#
#                           known_for_titles
# 0  tt8676446,tt7473716,tt2309260,tt2181752
# 1  tt0156427,tt0364120,tt2668120,tt2399533
# 2  tt2645542,tt3645918,tt3393372,tt2666286
# 3  tt0247911,tt3080284,tt4773064,tt1443519
# 4  tt2195548,tt2382396,tt0262432,tt1502407
#
# [5 rows x 24 columns]

# %%
BCN.describe(percentiles=[0.5, 0.95])
# Out:
#        production_budget  domestic_gross  worldwide_gross        month  \
# count       2.264000e+03    2.264000e+03     2.264000e+03  2264.000000
# mean        3.634814e+07    4.585684e+07     1.107782e+08     6.946555
# std         5.018637e+07    7.725420e+07     2.137773e+08     3.490188
# min         1.400000e+03    0.000000e+00     0.000000e+00     1.000000
# 50%         1.800000e+07    1.868050e+07     3.204126e+07     7.000000
# 95%         1.500000e+08    1.865600e+08     5.191983e+08    12.000000
# max         4.250000e+08    7.605076e+08     2.776345e+09    12.000000
#
#              Profit           ROI  runtime_minutes   birth_year   death_year
# count  2.264000e+03   2264.000000      2264.000000  1361.000000    20.000000
# mean   7.443011e+07    303.871589       101.708039  1965.833211  2014.950000
# std    1.773440e+08   1561.056298        22.080858    10.678770     2.625282
# min   -2.002376e+08   -100.000000         1.000000  1930.000000  2010.000000
# 50%    1.146207e+07     68.272731       101.000000  1967.000000  2015.000000
# 95%    3.884145e+08   1061.533602       137.000000  1981.000000  2019.000000
# max    2.351345e+09  41556.474000       180.000000  1998.000000  2019.000000

# %%
from matplotlib.legend_handler import HandlerLine2D

fx = sns.lineplot(x='Month', y='worldwide_gross', data=budgets.sort_values('month'), marker='o')
fx1 = sns.lineplot(x='Month', y='production_budget', data=budgets.sort_values('month'), marker='o')

plt.legend(handler_map={fx: HandlerLine2D(numpoints=12)})
# Out:
# No handles with labels found to put in legend.

# %%
g.set_xticklabels(g.get_xticklabels(), rotation=30)

# %%
BCN.head()
# Out:
#                       movie release_date  production_budget  domestic_gross  \
# 0               The Gallows   2015-07-10             100000        22764410
# 1                     Bambi   1942-08-13             858000       102797000
# 2  Night of the Living Dead   1968-10-01             114000        12087064
# 3                     Rocky   1976-11-21            1000000       117235147
# 4                 Halloween   1978-10-17             325000        47000000
#
#    worldwide_gross  month Month     Profit           ROI     tconst  ...  \
# 0         41656474      7   Jul   41556474  41556.474000  tt2309260  ...
# 1        268000000      8   Aug  267142000  31135.431235  tt2668120  ...
# 2         30087064     10   Oct   29973064  26292.161404  tt3393372  ...
# 3        225000000     11   Nov  224000000  22400.000000  tt3080284  ...
# 4         70000000     10   Oct   69675000  21438.461538  tt1502407  ...
#
#              directors                                            writers  \
# 0  nm4000389,nm3951039                                nm3951039,nm4000389
# 1            nm0509852                                          nm0509852
# 2            nm5209991                                          nm5209991
# 3            nm1126847                                                NaN
# 4            nm0337773  nm0000118,nm0384185,nm2171769,nm1144419,nm0337773
#
#            director_split  director1  director2        primary_name  \
# 0  [nm4000389, nm3951039]  nm4000389  nm3951039        Travis Cluff
# 1             [nm0509852]  nm0509852         NA  Sébastien Lifshitz
# 2             [nm5209991]  nm5209991         NA          Chad Zuver
# 3             [nm1126847]  nm1126847         NA        Sujit Mondal
# 4             [nm0337773]  nm0337773         NA  David Gordon Green
#
#   birth_year death_year                  primary_profession  \
# 0        NaN        NaN             producer,actor,director
# 1     1968.0        NaN               director,writer,actor
# 2        NaN        NaN               producer,actor,writer
# 3        NaN        NaN  assistant_director,director,writer
# 4     1975.0        NaN            producer,director,writer
#
#                           known_for_titles
# 0  tt8676446,tt7473716,tt2309260,tt2181752
# 1  tt0156427,tt0364120,tt2668120,tt2399533
# 2  tt2645542,tt3645918,tt3393372,tt2666286
# 3  tt0247911,tt3080284,tt4773064,tt1443519
# 4  tt2195548,tt2382396,tt0262432,tt1502407
#
# [5 rows x 24 columns]

# %%
sns.set_context('poster')
plt.figure(figsize=(15,10))
ax = sns.scatterplot(y'production_budget', x'ROI', hue='primary_name', data=BCN, legend=False).set(xlim=(0,200000000))
ax.set(xlim=(0,200000000))
ax.set(ylim(0,3500))
# Out:
#   File "<ipython-input-96-82c566c98ecd>", line 3
#     ax = sns.scatterplot(y'production_budget', x'ROI', hue='primary_name', data=BCN, legend=False).set(xlim=(0,200000000))
#                           ^
# SyntaxError: invalid syntax

# %%
sns.set_context('poster')
plt.figure(figsize=(15,10))
ax = sns.regplot(x='production_budget', y='ROI', data=BCN, robust=True, ci=68, truncate=True)
ax.set(xlim=(0,200000000))
ax.set(ylim=(0,1500))
# Out:
# [(0.0, 1500.0)]

# %%
ax = sns.jointplot(x='production_budget', y='ROI', data=BCN, marker="+", s=100, marginal_kws=(bins=250000, fill=False))
ax.set(xlim=(0,150000000))
ax.set(ylim=(0,1500))
# Out:
#   File "<ipython-input-126-a6306832a04e>", line 1
#     ax = sns.jointplot(x='production_budget', y='ROI', data=BCN, marker="+", s=100, marginal_kws=(bins=250000, fill=False))
#                                                                                                       ^
# SyntaxError: invalid syntax
